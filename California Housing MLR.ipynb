# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %%
calihouse = pd.read_csv("C:\\Users\\SHRISTI\\Desktop\\ML Internship\\EDA Practice\\california_housing.csv")
calihouse
# Out:
#        longitude  latitude  housing_age  total_rooms  total_bedrooms  \
# 0        -122.23     37.88           41          880           129.0
# 1        -122.22     37.86           21         7099          1106.0
# 2        -122.24     37.85           52         1467           190.0
# 3        -122.25     37.85           52         1274           235.0
# 4        -122.25     37.85           52         1627           280.0
# ...          ...       ...          ...          ...             ...
# 20635    -121.09     39.48           25         1665           374.0
# 20636    -121.21     39.49           18          697           150.0
# 20637    -121.22     39.43           17         2254           485.0
# 20638    -121.32     39.43           18         1860           409.0
# 20639    -121.24     39.37           16         2785           616.0
#
#        population  households  income  house_value ocean_proximity
# 0             322         126  8.3252       452600        NEAR BAY
# ...

# %%
calihouse.head()                   #finding the top 5 rows using head function
# Out:
#    longitude  latitude  housing_age  total_rooms  total_bedrooms  population  \
# 0    -122.23     37.88           41          880           129.0         322
# 1    -122.22     37.86           21         7099          1106.0        2401
# 2    -122.24     37.85           52         1467           190.0         496
# 3    -122.25     37.85           52         1274           235.0         558
# 4    -122.25     37.85           52         1627           280.0         565
#
#    households  income  house_value ocean_proximity
# 0         126  8.3252       452600        NEAR BAY
# 1        1138  8.3014       358500        NEAR BAY
# 2         177  7.2574       352100        NEAR BAY
# 3         219  5.6431       341300        NEAR BAY
# 4         259  3.8462       342200        NEAR BAY

# %%
calihouse.describe()                                #lesser counts due to missing values
# Out:
#           longitude      latitude   housing_age   total_rooms  total_bedrooms  \
# count  20640.000000  20640.000000  20640.000000  20640.000000    20433.000000
# mean    -119.569704     35.631861     28.639486   2635.763081      537.870553
# std        2.003532      2.135952     12.585558   2181.615252      421.385070
# min     -124.350000     32.540000      1.000000      2.000000        1.000000
# 25%     -121.800000     33.930000     18.000000   1447.750000      296.000000
# 50%     -118.490000     34.260000     29.000000   2127.000000      435.000000
# 75%     -118.010000     37.710000     37.000000   3148.000000      647.000000
# max     -114.310000     41.950000     52.000000  39320.000000     6445.000000
#
#          population    households        income    house_value
# count  20640.000000  20640.000000  20640.000000   20640.000000
# mean    1425.476744    499.539680      3.870671  206855.816909
# std     1132.462122    382.329753      1.899822  115395.615874
# ...

# %%
calihouse.shape                         #finding the shape of the data
# Out:
# (20640, 10)

# %%
calihouse.info()                     #finding the datatypes (object=categorical datatype)
                               #features having more missing values shouldn't be considered even if it is important
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 20640 entries, 0 to 20639
# Data columns (total 10 columns):
# longitude          20640 non-null float64
# latitude           20640 non-null float64
# housing_age        20640 non-null int64
# total_rooms        20640 non-null int64
# total_bedrooms     20433 non-null float64
# population         20640 non-null int64
# households         20640 non-null int64
# income             20640 non-null float64
# house_value        20640 non-null int64
# ocean_proximity    20640 non-null object
# dtypes: float64(4), int64(5), object(1)
# memory usage: 1.6+ MB

# %%
calihouse1 = calihouse.fillna('total_bedrooms')
calihouse1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 20640 entries, 0 to 20639
# Data columns (total 10 columns):
# longitude          20640 non-null float64
# latitude           20640 non-null float64
# housing_age        20640 non-null int64
# total_rooms        20640 non-null int64
# total_bedrooms     20640 non-null object
# population         20640 non-null int64
# households         20640 non-null int64
# income             20640 non-null float64
# house_value        20640 non-null int64
# ocean_proximity    20640 non-null object
# dtypes: float64(3), int64(5), object(2)
# memory usage: 1.6+ MB

# %%
sns.pairplot(calihouse)
# Out:
# C:\Users\SHRISTI\Anaconda3\lib\site-packages\numpy\lib\histograms.py:824: RuntimeWarning: invalid value encountered in greater_equal
#   keep = (tmp_a >= first_edge)
# C:\Users\SHRISTI\Anaconda3\lib\site-packages\numpy\lib\histograms.py:825: RuntimeWarning: invalid value encountered in less_equal
#   keep &= (tmp_a <= last_edge)

# %%
calihouse.corr()
# Out:
#                 longitude  latitude  housing_age  total_rooms  total_bedrooms  \
# longitude        1.000000 -0.924664    -0.108197     0.044568        0.069608
# latitude        -0.924664  1.000000     0.011173    -0.036100       -0.066983
# housing_age     -0.108197  0.011173     1.000000    -0.361262       -0.320451
# total_rooms      0.044568 -0.036100    -0.361262     1.000000        0.930380
# total_bedrooms   0.069608 -0.066983    -0.320451     0.930380        1.000000
# population       0.099773 -0.108785    -0.296244     0.857126        0.877747
# households       0.055310 -0.071035    -0.302916     0.918484        0.979728
# income          -0.015176 -0.079809    -0.119034     0.198050       -0.007723
# house_value     -0.045967 -0.144160     0.105623     0.134153        0.049686
#
#                 population  households    income  house_value
# longitude         0.099773    0.055310 -0.015176    -0.045967
# latitude         -0.108785   -0.071035 -0.079809    -0.144160
# ...

# %%
corr_matrix = calihouse.corr()
corr_matrix["house_value"].sort_values(ascending=False)             # - doesn't count
# Out:
# house_value       1.000000
# income            0.688075
# total_rooms       0.134153
# housing_age       0.105623
# households        0.065843
# total_bedrooms    0.049686
# population       -0.024650
# longitude        -0.045967
# latitude         -0.144160
# Name: house_value, dtype: float64

# %%
df.hist(bins = 50, figsize = (30,30))
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x000001AF0789C548>,
# ...
#       dtype=object)

# %%
plt.figure(figsize=[10,10])
sns.heatmap(corr_matrix,annot=True)

# %%
cali = calihouse.drop(['total_bedrooms'],axis=1)
cali
# Out:
#        longitude  latitude  housing_age  total_rooms  population  households  \
# 0        -122.23     37.88           41          880         322         126
# 1        -122.22     37.86           21         7099        2401        1138
# 2        -122.24     37.85           52         1467         496         177
# 3        -122.25     37.85           52         1274         558         219
# 4        -122.25     37.85           52         1627         565         259
# ...          ...       ...          ...          ...         ...         ...
# 20635    -121.09     39.48           25         1665         845         330
# 20636    -121.21     39.49           18          697         356         114
# 20637    -121.22     39.43           17         2254        1007         433
# 20638    -121.32     39.43           18         1860         741         349
# 20639    -121.24     39.37           16         2785        1387         530
#
#        income  house_value ocean_proximity
# ...

# %% [markdown]
# ### MLR

# %%
X = cali[['longitude','latitude','total_rooms','population','income','households','housing_age','ocean_proximity']]
y = cali['house_value']

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, y , test_size = 0.75, random_state = 42)

# %%
X_train.shape
# Out:
# (5160, 8)

# %%
y_train.shape
# Out:
# (5160,)

# %%
from sklearn.pipeline import Pipeline
from sklearn.impute import SimpleImputer
from sklearn.preprocessing import OneHotEncoder
from sklearn.preprocessing import StandardScaler

# %%
from sklearn.base import BaseEstimator, TransformerMixin

# %%
class MostFrequentImputer(BaseEstimator, TransformerMixin):
    def fit(self, X, y=None):
        self.most_frequent_ = pd.Series([X[c].value_counts().index[0] for c in X],index=X.columns)
        return self
    def transform(self, X, y=None):
        return X.fillna(self.most_frequent_)

# %%
cat_pipeline = Pipeline([
    ("imputer", MostFrequentImputer()),
    ("cat_encode", OneHotEncoder()),
])

# %%
num_pipeline = Pipeline([
    ("imputer", SimpleImputer(strategy='median')),
    ("std_scaler", StandardScaler()),
])

# %%
from sklearn.compose import ColumnTransformer
num_attribs = ['longitude','latitude','total_rooms','population','income','households','housing_age']
cat_attribs = ['ocean_proximity']
full_pipeline = ColumnTransformer([
    ('num',num_pipeline,num_attribs),
    ("cat",cat_pipeline,cat_attribs)
])

# %%
X_train_prep = full_pipeline.fit_transform(X_train)
X_train_prep.shape
# Out:
# (5160, 12)

# %%
import statsmodels.api as sm

X_train_sm = sm.add_constant(X_train_prep)
lr = sm.OLS(y_train, X_train_sm).fit()

# %%
lr.params
# Out:
# const    208413.534447
# x1       -43354.090481
# x2       -44132.757983
# x3        -2001.975431
# x4       -38947.067008
# x5        71981.175484
# x6        46008.943272
# x7        12454.139204
# x8        13355.021055
# x9       -33279.747757
# x10      198705.763740
# x11       11915.265317
# x12       17717.232091
# dtype: float64

# %%
lr.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ...
# Dep. Variable:            house_value   R-squared:                       0.630
# Model:                            OLS   Adj. R-squared:                  0.629
# Method:                 Least Squares   F-statistic:                     797.3
# Date:                Fri, 24 Jan 2020   Prob (F-statistic):               0.00
# Time:                        14:42:59   Log-Likelihood:                -64939.
# No. Observations:                5160   AIC:                         1.299e+05
# Df Residuals:                    5148   BIC:                         1.300e+05
# Df Model:                          11
# Covariance Type:            nonrobust
# ...
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const       2.084e+05   1.18e+04     17.596      0.000    1.85e+05    2.32e+05
# ...

# %%
print(lr.summary())
# Out:
#                             OLS Regression Results
# ...
# Dep. Variable:            house_value   R-squared:                       0.630
# Model:                            OLS   Adj. R-squared:                  0.629
# Method:                 Least Squares   F-statistic:                     797.3
# Date:                Fri, 24 Jan 2020   Prob (F-statistic):               0.00
# Time:                        14:42:59   Log-Likelihood:                -64939.
# No. Observations:                5160   AIC:                         1.299e+05
# Df Residuals:                    5148   BIC:                         1.300e+05
# Df Model:                          11
# Covariance Type:            nonrobust
# ...
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const       2.084e+05   1.18e+04     17.596      0.000    1.85e+05    2.32e+05
# ...

# %%
X_test_prep = full_pipeline.fit_transform(X_test)
X_test_prep.shape
# Out:
# (15480, 12)

# %%
X_test_sm = sm.add_constant(X_test_prep)

# %%
y_pred = lr.predict(X_test_sm)

# %%
from sklearn.metrics import mean_squared_error
from sklearn.metrics import r2_score

# %%
r2_score(y_test,y_pred)
# Out:
# 0.6459000698643995
